# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
# %timeit np.random.randn(10000)      # 微基准测试|
# Out:
# 180 μs ± 14.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%time
import time
time.sleep(0.5)
# Out:
# CPU times: user 1.18 ms, sys: 0 ns, total: 1.18 ms
# Wall time: 500 ms

# %% [markdown]
# 学习率 0.01, loss = 0.342
# $E = mc^2$

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,3))
plt.plot([1,2,3,4],[1,4,2,3], marker='o')
plt.title("inline plot"); plt.show()
